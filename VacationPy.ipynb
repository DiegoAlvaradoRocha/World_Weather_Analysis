# %%
pip install gmaps
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests

# Import the API key.
from config import g_key

# %%
# created the CSV you saved into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                 Date      Lat       Lng  \
# 0        0         Labuhan      ID  2021-06-04 00:54:33  -6.8844  112.2051
# 1        1  Quechultenango      MX  2021-06-04 00:54:34  17.4167  -99.2167
# 2        2        Araouane      ML  2021-06-04 00:54:34  18.9048   -3.5265
# 3        3    Punta Arenas      CL  2021-06-04 00:51:35 -53.1500  -70.9167
# 4        4  Kulhudhuffushi      MV  2021-06-04 00:54:34   6.6221   73.0700
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     82.62        75          97        9.42
# 1     72.93        90          66        3.94
# 2     95.76        16           9       10.09
# 3     35.71        93          90        9.10
# 4     82.51        75          98       18.68

# %%
# get the data type
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# 1. get the latitudes and longitudes
locations = city_data_df[["Lat", "Lng"]]

# 2. get the maximum temperature
max_temp = city_data_df["Max Temp"]

# 3. assign the figure variable.
fig = gmaps.figure()

# 4. assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights = max_temp)

# 5. add the headmap layer.
fig.add_layer(heat_layer)

# 6. call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp,0))

# %%
# Heatmap of temperature
# get the latitudes and longitudes
locations = city_data_df[["Lat", "Lng"]]

# get the maximum temperature
max_temp = city_data_df["Max Temp"]

# assign the figure variable.
fig = gmaps.figure(center = (30.0, 31.0), zoom_level = 1.5)

# assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights = temps, dissipating = False, max_intensity = 300, point_radius = 4)

# add the headmap layer.
fig.add_layer(heat_layer)

# call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of Humidity
# 1. get the latitudes and longitudes
locations = city_data_df[["Lat", "Lng"]]

# 2. get the maximum temperature
humidity = city_data_df["Humidity"]

# 3. assign the figure variable.
fig = gmaps.figure(center = (30.0, 31.0), zoom_level = 1.5)

# 4. assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights = humidity, dissipating = False, max_intensity = 300, point_radius = 4)

# 5. add the headmap layer.
fig.add_layer(heat_layer)

# 6. call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of cloudiness
# 1. get the latitudes and longitudes
locations = city_data_df[["Lat", "Lng"]]

# 2. get the maximum temperature
clouds = city_data_df["Cloudiness"]

# 3. assign the figure variable.
fig = gmaps.figure(center = (30,31), zoom_level = 1.5)

# 4. assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights = clouds, dissipating = False, max_intensity = 300, point_radius = 4 )

# 5. add the headmap layer.
fig.add_layer(heat_layer)

# 6. call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of wind Speed
# 1. get the latitudes and longitudes
locations = city_data_df[["Lat", "Lng"]]

# 2. get the maximum temperature
wind = city_data_df["Wind Speed"]

# 3. assign the figure variable.
fig = gmaps.figure(center = (30,31), zoom_level = 1.5)

# 4. assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights = wind, dissipating = False, max_intensity = 300, point_radius = 4)

# 5. add the heatmap layer.
fig.add_layer(heat_layer)

# 6. call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the costumer to add the minimum and maximum temperature vale.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp)&(city_data_df["Max Temp"]>= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 0         0         Labuhan      ID  2021-06-04 00:54:33  -6.8844  112.2051
# 4         4  Kulhudhuffushi      MV  2021-06-04 00:54:34   6.6221   73.0700
# 7         7          Atuona      PF  2021-06-04 00:54:35  -9.8000 -139.0333
# 13       13      Butaritari      KI  2021-06-04 00:50:30   3.0707  172.7902
# 18       18        Lorengau      PG  2021-06-04 00:50:08  -2.0226  147.2712
# 23       23          Shache      CN  2021-06-04 00:54:38  38.4167   77.2406
# 25       25      Georgetown      MY  2021-06-04 00:54:39   5.4112  100.3354
# 27       27          Cairns      AU  2021-06-04 00:54:39 -16.9167  145.7667
# 28       28          Riyadh      SA  2021-06-04 00:51:12  24.6877   46.7219
# 29       29           Kapaa      US  2021-06-04 00:54:40  22.0752 -159.3190
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 0      82.62        75          97        9.42
# ...

# %%
preferred_cities_df.count()
# Out:
# City_ID       197
# City          197
# Country       197
# Date          197
# Lat           197
# Lng           197
# Max Temp      197
# Humidity      197
# Cloudiness    197
# Wind Speed    197
# dtype: int64

# %%
# create a DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = " "
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Lat       Lng Hotel Name
# 0          Labuhan      ID     82.62  -6.8844  112.2051
# 4   Kulhudhuffushi      MV     82.51   6.6221   73.0700
# 7           Atuona      PF     79.72  -9.8000 -139.0333
# 13      Butaritari      KI     83.16   3.0707  172.7902
# 18        Lorengau      PG     84.81  -2.0226  147.2712
# 23          Shache      CN     75.04  38.4167   77.2406
# 25      Georgetown      MY     82.33   5.4112  100.3354
# 27          Cairns      AU     82.06 -16.9167  145.7667
# 28          Riyadh      SA     89.65  24.6877   46.7219
# 29           Kapaa      US     77.18  22.0752 -159.3190

# %%
# set the parameters to search for a hotel.
params = {
    "radius": 5000, 
    "type": "lodging", 
    "key" : g_key}

# %%
# iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # make a request and get the json data from the search.
    hotels = requests.get(base_url, params = params).json()
    
    # grab the first hotel from the result and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]     
    except(IndexError):
        print("Hotel not found ... skipping.")
# Out:
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.
# Hotel not found ... skipping.

# %%
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Lat       Lng  \
# 0          Labuhan      ID     82.62  -6.8844  112.2051
# 4   Kulhudhuffushi      MV     82.51   6.6221   73.0700
# 7           Atuona      PF     79.72  -9.8000 -139.0333
# 13      Butaritari      KI     83.16   3.0707  172.7902
# 18        Lorengau      PG     84.81  -2.0226  147.2712
# 23          Shache      CN     75.04  38.4167   77.2406
# 25      Georgetown      MY     82.33   5.4112  100.3354
# 27          Cairns      AU     82.06 -16.9167  145.7667
# 28          Riyadh      SA     89.65  24.6877   46.7219
# 29           Kapaa      US     77.18  22.0752 -159.3190
#
#                                Hotel Name
# 0                PT PPI Lamongan Tambak C
# 4                     Haajy Guest House 1
# 7                             Villa Enata
# 13                     Isles Sunset Lodge
# 18             Lorengau Harbourside Hotel
# 23                           Delong Hotel
# 25                         Cititel Penang
# ...

# %%
# Add a heatmap temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center = (30,31), zoom_level = 1.5)
heat_layer = gmaps.heatmap_layer(locations, weights = max_temp, dissipating = False, max_intensity = 300, point_radius = 4)

# Assing the marker variable
marker_layer = gmaps.marker_layer(locations)

fig.add_layer(heat_layer)

# add the marker layer
fig.add_layer(marker_layer)

# Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Assign multiple strings in thr info box template variable
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp}F</dd>
</dl>
"""

# %%
# Store the dataframe row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center = (30,31), zoom_level = 1.5)
heat_layer = gmaps.heatmap_layer(locations, weights = max_temp, dissipating = False, max_intensity = 300, point_radius = 4)

# Assing the marker variable with info box content
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)

fig.add_layer(heat_layer)

# add the marker layer
fig.add_layer(marker_layer)

# Call the figure to plot the data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
