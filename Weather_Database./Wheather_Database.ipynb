# %%
# import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# create a set of 2000 random latitude and longitud combinations
lats=np.random.uniform(low=-90.00, high=90.00, size=2000)
lngs=np.random.uniform(low=-180.00, high=180.00, size=2000)
lat_lngs=zip(lats,lngs)
lat_lngs

# add latitud and longitud to a list
coordinates=list(lat_lngs)

# %%
#impot citipy
from citipy import citipy

# create a list for holding the cities
cities=[]
# identify the nearest city for each latitudes and longitudes combinations.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique then we will add to the list.
    if city not in cities:
        cities.append(city)

# %%
# print the city count to confirm sufficient count.
len(cities)
# Out:
# 791

# %%
#import the request library
import requests

#import weather api key
from config import weather_apikey

#build the url for Weather Map API call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_apikey
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6facdbef2bed5aa347c4e428d80e64cd

# %%
# create an empty list to hold the weather data.
city_data = []

#print the beginning of the logging.
print("Beginning Data Retrieval   ")
print("------------------------")

#create counters.
record_count = 1
set_count = 1

#Loop through all the cities in our list.
for i in range(len(cities)):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    #create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

#Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in set of 50 for logging purposes.
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    #create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city.
    print(f"Prossing Record {record_count} of Set {set_count} | {city}")
    
    # add 1 to the record count.
    record_count += 1

# run an api request for each of the cities.
    try:
        #parse the json and retirve the data.
        city_weather = requests.get(city_url).json()
    
        #parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

    

        #Append the information into the city_data list.
        city_data.append({"City": city.title(), 
                          "Country": city_country,
                          "Lat": city_lat, "Lng": city_lng, "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description})
    
# if an error is experienced skip the city.
    except:
        print("city not found. Skipping...")
        pass
    
# indicate the data loading is complete.
print("---------------------------")
print("Data Retrieval complete    ")
print("---------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Prossing Record 1 of Set 16 | port augusta
# Prossing Record 2 of Set 16 | buluang
# Prossing Record 3 of Set 16 | mataura
# Prossing Record 4 of Set 16 | kapaa
# Prossing Record 5 of Set 16 | yelizovo
# Prossing Record 6 of Set 16 | bredasdorp
# Prossing Record 7 of Set 16 | petropavlovsk-kamchatskiy
# Prossing Record 8 of Set 16 | abnub
# Prossing Record 9 of Set 16 | rikitea
# Prossing Record 10 of Set 16 | castro
# Prossing Record 11 of Set 16 | fortuna
# Prossing Record 12 of Set 16 | hobart
# Prossing Record 13 of Set 16 | samalaeulu
# city not found. Skipping...
# Prossing Record 14 of Set 16 | norman wells
# Prossing Record 15 of Set 16 | mayo
# Prossing Record 16 of Set 16 | tuktoyaktuk
# Prossing Record 17 of Set 16 | yellowknife
# Prossing Record 18 of Set 16 | atuona
# Prossing Record 19 of Set 16 | katsuura
# Prossing Record 20 of Set 16 | hermanus
# Prossing Record 21 of Set 16 | jaque
# Prossing Record 22 of Set 16 | bengkulu
# Prossing Record 23 of Set 16 | hilo
# Prossing Record 24 of Set 16 | taolanaro
# city not found. Skipping...
# Prossing Record 25 of Set 16 | krasnoarmeysk
# Prossing Record 26 of Set 16 | riyadh
# Prossing Record 27 of Set 16 | sembe
# Prossing Record 28 of Set 16 | provost
# Prossing Record 29 of Set 16 | esmeraldas
# Prossing Record 30 of Set 16 | miri
# Prossing Record 31 of Set 16 | khatanga
# Prossing Record 32 of Set 16 | albany
# Prossing Record 33 of Set 16 | nabul
# city not found. Skipping...
# Prossing Record 34 of Set 16 | avarua
# Prossing Record 35 of Set 16 | bluff
# Prossing Record 36 of Set 16 | grand river south east
# city not found. Skipping...
# Prossing Record 37 of Set 16 | gamba
# Prossing Record 38 of Set 16 | saskylakh
# Prossing Record 39 of Set 16 | barrow
# Prossing Record 40 of Set 16 | ushuaia
# Prossing Record 41 of Set 16 | punta arenas
# Prossing Record 42 of Set 16 | hamilton
# Prossing Record 43 of Set 16 | bonavista
# Prossing Record 44 of Set 16 | samusu
# city not found. Skipping...
# Prossing Record 45 of Set 16 | wanaka
# Prossing Record 46 of Set 16 | new norfolk
# Prossing Record 47 of Set 16 | busselton
# Prossing Record 48 of Set 16 | caravelas
# Prossing Record 49 of Set 16 | lebu
# Prossing Record 50 of Set 16 | saryg-sep
# Prossing Record 1 of Set 17 | talcahuano
# Prossing Record 2 of Set 17 | thompson
# Prossing Record 3 of Set 17 | kruisfontein
# Prossing Record 4 of Set 17 | puerto maldonado
# Prossing Record 5 of Set 17 | puerto ayora
# Prossing Record 6 of Set 17 | port alfred
# Prossing Record 7 of Set 17 | mount gambier
# Prossing Record 8 of Set 17 | terracina
# Prossing Record 9 of Set 17 | bangassou
# Prossing Record 10 of Set 17 | illoqqortoormiut
# city not found. Skipping...
# Prossing Record 11 of Set 17 | batalha
# Prossing Record 12 of Set 17 | hithadhoo
# Prossing Record 13 of Set 17 | itoman
# Prossing Record 14 of Set 17 | jamestown
# Prossing Record 15 of Set 17 | moncton
# Prossing Record 16 of Set 17 | guerrero negro
# Prossing Record 17 of Set 17 | kununurra
# Prossing Record 18 of Set 17 | kamenskoye
# city not found. Skipping...
# Prossing Record 19 of Set 17 | victoria
# Prossing Record 20 of Set 17 | duz
# city not found. Skipping...
# Prossing Record 21 of Set 17 | tsihombe
# city not found. Skipping...
# Prossing Record 22 of Set 17 | port elizabeth
# Prossing Record 23 of Set 17 | vaitupu
# city not found. Skipping...
# Prossing Record 24 of Set 17 | pasni
# Prossing Record 25 of Set 17 | itubera
# Prossing Record 26 of Set 17 | garwa
# Prossing Record 27 of Set 17 | butaritari
# Prossing Record 28 of Set 17 | nikolskoye
# Prossing Record 29 of Set 17 | emba
# Prossing Record 30 of Set 17 | talnakh
# Prossing Record 31 of Set 17 | barentsburg
# city not found. Skipping...
# Prossing Record 32 of Set 17 | penzance
# Prossing Record 33 of Set 17 | mackenzie
# Prossing Record 34 of Set 17 | havelock
# Prossing Record 35 of Set 17 | geraldton
# Prossing Record 36 of Set 17 | ribeira grande
# Prossing Record 37 of Set 17 | pevek
# Prossing Record 38 of Set 17 | belushya guba
# city not found. Skipping...
# Prossing Record 39 of Set 17 | severo-kurilsk
# Prossing Record 40 of Set 17 | cagayan de tawi-tawi
# city not found. Skipping...
# Prossing Record 41 of Set 17 | chapais
# Prossing Record 42 of Set 17 | bubaque
# Prossing Record 43 of Set 17 | airai
# Prossing Record 44 of Set 17 | husavik
# Prossing Record 45 of Set 17 | baruun-urt
# Prossing Record 46 of Set 17 | cape town
# Prossing Record 47 of Set 17 | leghorn
# city not found. Skipping...
# Prossing Record 48 of Set 17 | arenys de mar
# Prossing Record 49 of Set 17 | ilulissat
# Prossing Record 50 of Set 17 | port lincoln
# Prossing Record 1 of Set 18 | natal
# Prossing Record 2 of Set 18 | mahibadhoo
# Prossing Record 3 of Set 18 | comodoro rivadavia
# Prossing Record 4 of Set 18 | nouadhibou
# Prossing Record 5 of Set 18 | bud
# Prossing Record 6 of Set 18 | umzimvubu
# city not found. Skipping...
# Prossing Record 7 of Set 18 | sao joao da barra
# Prossing Record 8 of Set 18 | half moon bay
# Prossing Record 9 of Set 18 | sorong
# Prossing Record 10 of Set 18 | sao filipe
# Prossing Record 11 of Set 18 | padang
# Prossing Record 12 of Set 18 | sungairaya
# Prossing Record 13 of Set 18 | porto
# Prossing Record 14 of Set 18 | estelle
# Prossing Record 15 of Set 18 | chernyatyn
# Prossing Record 16 of Set 18 | kargopol
# Prossing Record 17 of Set 18 | brae
# Prossing Record 18 of Set 18 | ejea de los caballeros
# Prossing Record 19 of Set 18 | cairns
# Prossing Record 20 of Set 18 | roebourne
# Prossing Record 21 of Set 18 | flinders
# Prossing Record 22 of Set 18 | tura
# Prossing Record 23 of Set 18 | bolungarvik
# city not found. Skipping...
# Prossing Record 24 of Set 18 | mar del plata
# Prossing Record 25 of Set 18 | tocopilla
# Prossing Record 26 of Set 18 | solnechnyy
# Prossing Record 27 of Set 18 | tumannyy
# city not found. Skipping...
# Prossing Record 28 of Set 18 | east london
# Prossing Record 29 of Set 18 | khonuu
# city not found. Skipping...
# Prossing Record 30 of Set 18 | selma
# Prossing Record 31 of Set 18 | saleaula
# city not found. Skipping...
# Prossing Record 32 of Set 18 | qaanaaq
# Prossing Record 33 of Set 18 | sioux lookout
# Prossing Record 34 of Set 18 | araouane
# Prossing Record 35 of Set 18 | yar-sale
# Prossing Record 36 of Set 18 | faanui
# Prossing Record 37 of Set 18 | ambodifototra
# city not found. Skipping...
# Prossing Record 38 of Set 18 | sarakhs
# Prossing Record 39 of Set 18 | kodiak
# Prossing Record 40 of Set 18 | ancud
# Prossing Record 41 of Set 18 | chau doc
# Prossing Record 42 of Set 18 | mahebourg
# Prossing Record 43 of Set 18 | illapel
# Prossing Record 44 of Set 18 | marawi
# Prossing Record 45 of Set 18 | ukiah
# Prossing Record 46 of Set 18 | marsh harbour
# Prossing Record 47 of Set 18 | reyes
# Prossing Record 48 of Set 18 | provideniya
# Prossing Record 49 of Set 18 | alamosa
# Prossing Record 50 of Set 18 | juneau
# Prossing Record 1 of Set 19 | vila velha
# Prossing Record 2 of Set 19 | karamea
# city not found. Skipping...
# Prossing Record 3 of Set 19 | hasaki
# Prossing Record 4 of Set 19 | lompoc
# Prossing Record 5 of Set 19 | del rio
# Prossing Record 6 of Set 19 | finsterwalde
# Prossing Record 7 of Set 19 | takoradi
# Prossing Record 8 of Set 19 | gazojak
# Prossing Record 9 of Set 19 | conceicao do araguaia
# Prossing Record 10 of Set 19 | amderma
# city not found. Skipping...
# Prossing Record 11 of Set 19 | bambanglipuro
# Prossing Record 12 of Set 19 | payakumbuh
# Prossing Record 13 of Set 19 | dongying
# Prossing Record 14 of Set 19 | aguimes
# Prossing Record 15 of Set 19 | falealupo
# city not found. Skipping...
# Prossing Record 16 of Set 19 | arlit
# Prossing Record 17 of Set 19 | ponta do sol
# Prossing Record 18 of Set 19 | egvekinot
# Prossing Record 19 of Set 19 | saint-philippe
# Prossing Record 20 of Set 19 | solovetskiy
# city not found. Skipping...
# Prossing Record 21 of Set 19 | saint george
# Prossing Record 22 of Set 19 | dingle
# Prossing Record 23 of Set 19 | morki
# Prossing Record 24 of Set 19 | huaihua
# Prossing Record 25 of Set 19 | oktyabrskiy
# Prossing Record 26 of Set 19 | antofagasta
# Prossing Record 27 of Set 19 | churapcha
# Prossing Record 28 of Set 19 | matara
# Prossing Record 29 of Set 19 | whitley bay
# Prossing Record 30 of Set 19 | berlevag
# Prossing Record 31 of Set 19 | cartagena
# Prossing Record 32 of Set 19 | chernyshevskiy
# Prossing Record 33 of Set 19 | skalistyy
# city not found. Skipping...
# Prossing Record 34 of Set 19 | upernavik
# Prossing Record 35 of Set 19 | abha
# Prossing Record 36 of Set 19 | maragogi
# Prossing Record 37 of Set 19 | inuvik
# Prossing Record 38 of Set 19 | tabas
# Prossing Record 39 of Set 19 | rawson
# Prossing Record 40 of Set 19 | gualeguaychu
# Prossing Record 41 of Set 19 | zemio
# Prossing Record 42 of Set 19 | torbay
# Prossing Record 43 of Set 19 | tiksi
# Prossing Record 44 of Set 19 | portland
# Prossing Record 45 of Set 19 | galatas
# Prossing Record 46 of Set 19 | sao felix do xingu
# Prossing Record 47 of Set 19 | tasiilaq
# Prossing Record 48 of Set 19 | tarudant
# city not found. Skipping...
# Prossing Record 49 of Set 19 | maksatikha
# Prossing Record 50 of Set 19 | kavieng
# Prossing Record 1 of Set 20 | cidreira
# Prossing Record 2 of Set 20 | ust-nera
# Prossing Record 3 of Set 20 | tromso
# Prossing Record 4 of Set 20 | srednekolymsk
# Prossing Record 5 of Set 20 | coihaique
# Prossing Record 6 of Set 20 | golden
# Prossing Record 7 of Set 20 | vostok
# Prossing Record 8 of Set 20 | chuy
# Prossing Record 9 of Set 20 | ahuimanu
# Prossing Record 10 of Set 20 | trairi
# Prossing Record 11 of Set 20 | monrovia
# Prossing Record 12 of Set 20 | san cristobal
# Prossing Record 13 of Set 20 | baft
# Prossing Record 14 of Set 20 | sharan
# Prossing Record 15 of Set 20 | cockburn harbour
# city not found. Skipping...
# Prossing Record 16 of Set 20 | harper
# Prossing Record 17 of Set 20 | nanortalik
# Prossing Record 18 of Set 20 | florida
# Prossing Record 19 of Set 20 | asau
# Prossing Record 20 of Set 20 | pangnirtung
# Prossing Record 21 of Set 20 | prnjavor
# Prossing Record 22 of Set 20 | hay river
# Prossing Record 23 of Set 20 | lumphat
# Prossing Record 24 of Set 20 | lugovoy
# Prossing Record 25 of Set 20 | vao
# Prossing Record 26 of Set 20 | iguatemi
# Prossing Record 27 of Set 20 | mareeba
# Prossing Record 28 of Set 20 | santa ines
# Prossing Record 29 of Set 20 | poretskoye
# Prossing Record 30 of Set 20 | cabo rojo
# Prossing Record 31 of Set 20 | cherskiy
# Prossing Record 32 of Set 20 | westport
# Prossing Record 33 of Set 20 | champerico
# Prossing Record 34 of Set 20 | vanimo
# Prossing Record 35 of Set 20 | codajas
# Prossing Record 36 of Set 20 | marcona
# city not found. Skipping...
# Prossing Record 37 of Set 20 | nanchang
# Prossing Record 38 of Set 20 | malabugas
# Prossing Record 39 of Set 20 | fairbanks
# Prossing Record 40 of Set 20 | cap malheureux
# Prossing Record 41 of Set 20 | nassjo
# Prossing Record 42 of Set 20 | attawapiskat
# city not found. Skipping...
# Prossing Record 43 of Set 20 | miguel hidalgo
# Prossing Record 44 of Set 20 | bonao
# Prossing Record 45 of Set 20 | tahta
# Prossing Record 46 of Set 20 | pedernales
# Prossing Record 47 of Set 20 | molteno
# Prossing Record 48 of Set 20 | karratha
# Prossing Record 49 of Set 20 | kaitangata
# Prossing Record 50 of Set 20 | calabozo
# Prossing Record 1 of Set 21 | chokurdakh
# Prossing Record 2 of Set 21 | maykain
# city not found. Skipping...
# Prossing Record 3 of Set 21 | klaksvik
# Prossing Record 4 of Set 21 | orbetello
# Prossing Record 5 of Set 21 | las juntas
# Prossing Record 6 of Set 21 | souillac
# Prossing Record 7 of Set 21 | brigantine
# Prossing Record 8 of Set 21 | menongue
# Prossing Record 9 of Set 21 | carnarvon
# Prossing Record 10 of Set 21 | isangel
# Prossing Record 11 of Set 21 | sivas
# Prossing Record 12 of Set 21 | yerkoy
# Prossing Record 13 of Set 21 | broome
# Prossing Record 14 of Set 21 | carutapera
# Prossing Record 15 of Set 21 | guangyuan
# Prossing Record 16 of Set 21 | cantapoy
# Prossing Record 17 of Set 21 | tabiauea
# city not found. Skipping...
# Prossing Record 18 of Set 21 | gat
# Prossing Record 19 of Set 21 | sur
# Prossing Record 20 of Set 21 | roma
# Prossing Record 21 of Set 21 | porto santo
# Prossing Record 22 of Set 21 | saharsa
# Prossing Record 23 of Set 21 | cumberland
# Prossing Record 24 of Set 21 | ostrovnoy
# Prossing Record 25 of Set 21 | bima
# Prossing Record 26 of Set 21 | tigil
# Prossing Record 27 of Set 21 | dikson
# Prossing Record 28 of Set 21 | novo aripuana
# Prossing Record 29 of Set 21 | hastings
# Prossing Record 30 of Set 21 | leningradskiy
# Prossing Record 31 of Set 21 | tuatapere
# Prossing Record 32 of Set 21 | sibu
# Prossing Record 33 of Set 21 | luorong
# Prossing Record 34 of Set 21 | mahajanga
# Prossing Record 35 of Set 21 | bambous virieux
# Prossing Record 36 of Set 21 | san quintin
# Prossing Record 37 of Set 21 | figline valdarno
# Prossing Record 38 of Set 21 | balabac
# Prossing Record 39 of Set 21 | sitka
# Prossing Record 40 of Set 21 | treinta y tres
# Prossing Record 41 of Set 21 | san patricio
# Prossing Record 42 of Set 21 | kenora
# Prossing Record 43 of Set 21 | svetlyy
# Prossing Record 44 of Set 21 | vila
# Prossing Record 45 of Set 21 | nizhneyansk
# city not found. Skipping...
# Prossing Record 46 of Set 21 | mitsamiouli
# Prossing Record 47 of Set 21 | aneho
# Prossing Record 48 of Set 21 | raudeberg
# Prossing Record 49 of Set 21 | cabo san lucas
# Prossing Record 50 of Set 21 | tanda
# Prossing Record 1 of Set 22 | itaituba
# Prossing Record 2 of Set 22 | micheweni
# Prossing Record 3 of Set 22 | sentyabrskiy
# city not found. Skipping...
# Prossing Record 4 of Set 22 | taburi
# city not found. Skipping...
# Prossing Record 5 of Set 22 | casper
# Prossing Record 6 of Set 22 | kieta
# Prossing Record 7 of Set 22 | vila franca do campo
# Prossing Record 8 of Set 22 | vaini
# Prossing Record 9 of Set 22 | georgetown
# Prossing Record 10 of Set 22 | cayenne
# Prossing Record 11 of Set 22 | la ronge
# Prossing Record 12 of Set 22 | longyearbyen
# Prossing Record 13 of Set 22 | isla mujeres
# Prossing Record 14 of Set 22 | xuanhua
# Prossing Record 15 of Set 22 | ngunguru
# Prossing Record 16 of Set 22 | lata
# Prossing Record 17 of Set 22 | warrnambool
# Prossing Record 18 of Set 22 | olginskaya
# Prossing Record 19 of Set 22 | puerto escondido
# Prossing Record 20 of Set 22 | iqaluit
# Prossing Record 21 of Set 22 | ladario
# Prossing Record 22 of Set 22 | tres arroyos
# Prossing Record 23 of Set 22 | kuche
# city not found. Skipping...
# Prossing Record 24 of Set 22 | grand gaube
# Prossing Record 25 of Set 22 | mashhad
# Prossing Record 26 of Set 22 | codrington
# Prossing Record 27 of Set 22 | kribi
# Prossing Record 28 of Set 22 | ankang
# Prossing Record 29 of Set 22 | nantucket
# Prossing Record 30 of Set 22 | tazovskiy
# Prossing Record 31 of Set 22 | porto belo
# Prossing Record 32 of Set 22 | alugan
# Prossing Record 33 of Set 22 | manokwari
# Prossing Record 34 of Set 22 | noyabrsk
# Prossing Record 35 of Set 22 | roanoke rapids
# Prossing Record 36 of Set 22 | navahrudak
# Prossing Record 37 of Set 22 | faya
# Prossing Record 38 of Set 22 | mecca
# Prossing Record 39 of Set 22 | mbeya
# Prossing Record 40 of Set 22 | shetpe
# Prossing Record 41 of Set 22 | kapoeta
# Prossing Record 42 of Set 22 | honiara
# Prossing Record 43 of Set 22 | the valley
# Prossing Record 44 of Set 22 | jizan
# Prossing Record 45 of Set 22 | ylivieska
# Prossing Record 46 of Set 22 | belaya gora
# Prossing Record 47 of Set 22 | atar
# Prossing Record 48 of Set 22 | berat
# Prossing Record 49 of Set 22 | voyvozh
# Prossing Record 50 of Set 22 | danilovka
# Prossing Record 1 of Set 23 | san-pedro
# Prossing Record 2 of Set 23 | malakal
# Prossing Record 3 of Set 23 | clarence town
# Prossing Record 4 of Set 23 | lake havasu city
# Prossing Record 5 of Set 23 | nedjo
# Prossing Record 6 of Set 23 | rundu
# Prossing Record 7 of Set 23 | ulaangom
# Prossing Record 8 of Set 23 | tunduru
# city not found. Skipping...
# Prossing Record 9 of Set 23 | moron
# Prossing Record 10 of Set 23 | umm lajj
# Prossing Record 11 of Set 23 | canatlan
# Prossing Record 12 of Set 23 | damaturu
# Prossing Record 13 of Set 23 | plouzane
# Prossing Record 14 of Set 23 | roald
# Prossing Record 15 of Set 23 | joshimath
# Prossing Record 16 of Set 23 | manaure
# Prossing Record 17 of Set 23 | noumea
# Prossing Record 18 of Set 23 | huntington
# Prossing Record 19 of Set 23 | sobolevo
# Prossing Record 20 of Set 23 | muroto
# Prossing Record 21 of Set 23 | sulurpeta
# city not found. Skipping...
# Prossing Record 22 of Set 23 | longlac
# city not found. Skipping...
# Prossing Record 23 of Set 23 | barkly west
# Prossing Record 24 of Set 23 | denpasar
# Prossing Record 25 of Set 23 | bereznehuvate
# Prossing Record 26 of Set 23 | flic en flac
# Prossing Record 27 of Set 23 | maryville
# Prossing Record 28 of Set 23 | oklahoma city
# Prossing Record 29 of Set 23 | preobrazhenskaya
# city not found. Skipping...
# Prossing Record 30 of Set 23 | bilibino
# Prossing Record 31 of Set 23 | kavaratti
# Prossing Record 32 of Set 23 | hambantota
# Prossing Record 33 of Set 23 | mehamn
# Prossing Record 34 of Set 23 | kuusamo
# Prossing Record 35 of Set 23 | russell
# Prossing Record 36 of Set 23 | raga
# Prossing Record 37 of Set 23 | forestville
# Prossing Record 38 of Set 23 | yuancheng
# Prossing Record 39 of Set 23 | vilhena
# Prossing Record 40 of Set 23 | ust-maya
# Prossing Record 41 of Set 23 | esperance
# Prossing Record 42 of Set 23 | oistins
# Prossing Record 43 of Set 23 | la rioja
# Prossing Record 44 of Set 23 | wum
# Prossing Record 45 of Set 23 | ghogha
# Prossing Record 46 of Set 23 | erzin
# Prossing Record 47 of Set 23 | thinadhoo
# Prossing Record 48 of Set 23 | lagoa
# Prossing Record 49 of Set 23 | buala
# Prossing Record 50 of Set 23 | manzanillo
# Prossing Record 1 of Set 24 | inirida
# Prossing Record 2 of Set 24 | ayer itam
# city not found. Skipping...
# Prossing Record 3 of Set 24 | santarem
# Prossing Record 4 of Set 24 | dhule
# Prossing Record 5 of Set 24 | shymkent
# Prossing Record 6 of Set 24 | novoagansk
# Prossing Record 7 of Set 24 | dzhebariki-khaya
# Prossing Record 8 of Set 24 | touros
# Prossing Record 9 of Set 24 | richards bay
# Prossing Record 10 of Set 24 | hammerfest
# Prossing Record 11 of Set 24 | mayumba
# Prossing Record 12 of Set 24 | port blair
# Prossing Record 13 of Set 24 | sechura
# Prossing Record 14 of Set 24 | north bend
# Prossing Record 15 of Set 24 | pontal do parana
# Prossing Record 16 of Set 24 | broken hill
# Prossing Record 17 of Set 24 | margate
# Prossing Record 18 of Set 24 | los llanos de aridane
# Prossing Record 19 of Set 24 | arraial do cabo
# Prossing Record 20 of Set 24 | inhambane
# Prossing Record 21 of Set 24 | zhuhai
# Prossing Record 22 of Set 24 | karpogory
# Prossing Record 23 of Set 24 | pombal
# Prossing Record 24 of Set 24 | adrar
# Prossing Record 25 of Set 24 | beringovskiy
# Prossing Record 26 of Set 24 | tual
# Prossing Record 27 of Set 24 | dunedin
# Prossing Record 28 of Set 24 | bargal
# city not found. Skipping...
# Prossing Record 29 of Set 24 | maningrida
# Prossing Record 30 of Set 24 | chanika
# Prossing Record 31 of Set 24 | tourlaville
# Prossing Record 32 of Set 24 | cortez
# Prossing Record 33 of Set 24 | road town
# Prossing Record 34 of Set 24 | oranjemund
# Prossing Record 35 of Set 24 | salalah
# Prossing Record 36 of Set 24 | dzaoudzi
# Prossing Record 37 of Set 24 | cockburn town
# Prossing Record 38 of Set 24 | chumikan
# Prossing Record 39 of Set 24 | kallupatti
# Prossing Record 40 of Set 24 | aki
# Prossing Record 41 of Set 24 | port lavaca
# Prossing Record 42 of Set 24 | kimry
# Prossing Record 43 of Set 24 | alofi
# Prossing Record 44 of Set 24 | ratnagiri
# Prossing Record 45 of Set 24 | turukhansk
# Prossing Record 46 of Set 24 | sabancuy
# Prossing Record 47 of Set 24 | totness
# Prossing Record 48 of Set 24 | pisco
# Prossing Record 49 of Set 24 | vestmannaeyjar
# Prossing Record 50 of Set 24 | borlange
# city not found. Skipping...
# Prossing Record 1 of Set 25 | teguise
# Prossing Record 2 of Set 25 | arkhipo-osipovka
# Prossing Record 3 of Set 25 | sumbawa
# city not found. Skipping...
# Prossing Record 4 of Set 25 | nhulunbuy
# Prossing Record 5 of Set 25 | ridgecrest
# Prossing Record 6 of Set 25 | kampong thum
# Prossing Record 7 of Set 25 | temiscaming
# Prossing Record 8 of Set 25 | camocim
# Prossing Record 9 of Set 25 | uvira
# Prossing Record 10 of Set 25 | dibulla
# Prossing Record 11 of Set 25 | zheleznodorozhnyy
# Prossing Record 12 of Set 25 | lana
# Prossing Record 13 of Set 25 | muros
# Prossing Record 14 of Set 25 | haibowan
# city not found. Skipping...
# Prossing Record 15 of Set 25 | coquimbo
# Prossing Record 16 of Set 25 | esna
# Prossing Record 17 of Set 25 | ust-kamchatsk
# city not found. Skipping...
# Prossing Record 18 of Set 25 | havre-saint-pierre
# Prossing Record 19 of Set 25 | hovd
# Prossing Record 20 of Set 25 | pemba
# Prossing Record 21 of Set 25 | thornhill
# Prossing Record 22 of Set 25 | opuwo
# Prossing Record 23 of Set 25 | clyde river
# Prossing Record 24 of Set 25 | teya
# Prossing Record 25 of Set 25 | binabalian
# Prossing Record 26 of Set 25 | basco
# Prossing Record 27 of Set 25 | lolua
# city not found. Skipping...
# Prossing Record 28 of Set 25 | orocue
# Prossing Record 29 of Set 25 | saint-augustin
# Prossing Record 30 of Set 25 | yomitan
# city not found. Skipping...
# Prossing Record 31 of Set 25 | trenggalek
# Prossing Record 32 of Set 25 | aklavik
# Prossing Record 33 of Set 25 | kiama
# Prossing Record 34 of Set 25 | tigre
# Prossing Record 35 of Set 25 | iranshahr
# Prossing Record 36 of Set 25 | odweyne
# Prossing Record 37 of Set 25 | mont-de-marsan
# Prossing Record 38 of Set 25 | karakol
# Prossing Record 39 of Set 25 | biak
# Prossing Record 40 of Set 25 | higuey
# city not found. Skipping...
# Prossing Record 41 of Set 25 | gorom-gorom
# Prossing Record 42 of Set 25 | ormara
# Prossing Record 43 of Set 25 | wewak
# Prossing Record 44 of Set 25 | bethel
# Prossing Record 45 of Set 25 | wawina
# Prossing Record 46 of Set 25 | san miguel
# Prossing Record 47 of Set 25 | paamiut
# Prossing Record 48 of Set 25 | sao desiderio
# Prossing Record 49 of Set 25 | swan hill
# Prossing Record 50 of Set 25 | lazaro cardenas
# Prossing Record 1 of Set 26 | gangoh
# Prossing Record 2 of Set 26 | logan lake
# Prossing Record 3 of Set 26 | leh
# Prossing Record 4 of Set 26 | gorno-chuyskiy
# city not found. Skipping...
# Prossing Record 5 of Set 26 | quatre cocos
# Prossing Record 6 of Set 26 | hami
# Prossing Record 7 of Set 26 | liverpool
# Prossing Record 8 of Set 26 | pouembout
# Prossing Record 9 of Set 26 | saint-gaudens
# Prossing Record 10 of Set 26 | tornio
# Prossing Record 11 of Set 26 | neuquen
# Prossing Record 12 of Set 26 | deputatskiy
# Prossing Record 13 of Set 26 | ambon
# Prossing Record 14 of Set 26 | harnosand
# Prossing Record 15 of Set 26 | simplicio mendes
# Prossing Record 16 of Set 26 | briancon
# Prossing Record 17 of Set 26 | tucuman
# Prossing Record 18 of Set 26 | acapulco
# Prossing Record 19 of Set 26 | mackay
# Prossing Record 20 of Set 26 | kutum
# Prossing Record 21 of Set 26 | maniitsoq
# Prossing Record 22 of Set 26 | mount darwin
# Prossing Record 23 of Set 26 | novyy urgal
# Prossing Record 24 of Set 26 | boende
# Prossing Record 25 of Set 26 | nishihara
# Prossing Record 26 of Set 26 | tawnat
# city not found. Skipping...
# Prossing Record 27 of Set 26 | verkhnyaya inta
# Prossing Record 28 of Set 26 | praia da vitoria
# Prossing Record 29 of Set 26 | novikovo
# Prossing Record 30 of Set 26 | dubbo
# Prossing Record 31 of Set 26 | blythe
# Prossing Record 32 of Set 26 | imperia
# Prossing Record 33 of Set 26 | paracuru
# Prossing Record 34 of Set 26 | savannah bight
# Prossing Record 35 of Set 26 | te anau
# Prossing Record 36 of Set 26 | christchurch
# Prossing Record 37 of Set 26 | labuhan
# Prossing Record 38 of Set 26 | goderich
# Prossing Record 39 of Set 26 | gohpur
# Prossing Record 40 of Set 26 | sept-iles
# Prossing Record 41 of Set 26 | plettenberg bay
# Prossing Record 42 of Set 26 | okato
# Prossing Record 43 of Set 26 | banda aceh
# Prossing Record 44 of Set 26 | nemuro
# Prossing Record 45 of Set 26 | elmira
# Prossing Record 46 of Set 26 | anlu
# Prossing Record 47 of Set 26 | maarianhamina
# Prossing Record 48 of Set 26 | kyshtovka
# Prossing Record 49 of Set 26 | hualmay
# Prossing Record 50 of Set 26 | bidhuna
# Prossing Record 1 of Set 27 | romny
# Prossing Record 2 of Set 27 | mosetse
# Prossing Record 3 of Set 27 | ca mau
# Prossing Record 4 of Set 27 | abohar
# Prossing Record 5 of Set 27 | mount isa
# Prossing Record 6 of Set 27 | columbus
# Prossing Record 7 of Set 27 | kalabo
# Prossing Record 8 of Set 27 | brooks
# Prossing Record 9 of Set 27 | ambilobe
# Prossing Record 10 of Set 27 | vieste
# Prossing Record 11 of Set 27 | dongsheng
# Prossing Record 12 of Set 27 | bandarbeyla
# Prossing Record 13 of Set 27 | cauquenes
# Prossing Record 14 of Set 27 | koumac
# Prossing Record 15 of Set 27 | vardo
# Prossing Record 16 of Set 27 | tabou
# Prossing Record 17 of Set 27 | esil
# Prossing Record 18 of Set 27 | namibe
# Prossing Record 19 of Set 27 | adrian
# Prossing Record 20 of Set 27 | aden
# Prossing Record 21 of Set 27 | komsomolskiy
# Prossing Record 22 of Set 27 | myronivka
# Prossing Record 23 of Set 27 | el alto
# Prossing Record 24 of Set 27 | kiunga
# Prossing Record 25 of Set 27 | bang saphan
# Prossing Record 26 of Set 27 | kamensk-shakhtinskiy
# Prossing Record 27 of Set 27 | yunyang
# Prossing Record 28 of Set 27 | pochutla
# Prossing Record 29 of Set 27 | rocha
# Prossing Record 30 of Set 27 | karur
# Prossing Record 31 of Set 27 | gangotri
# city not found. Skipping...
# Prossing Record 32 of Set 27 | ayorou
# Prossing Record 33 of Set 27 | okha
# Prossing Record 34 of Set 27 | luanda
# Prossing Record 35 of Set 27 | batagay-alyta
# Prossing Record 36 of Set 27 | grand-lahou
# Prossing Record 37 of Set 27 | garowe
# Prossing Record 38 of Set 27 | bo phloi
# Prossing Record 39 of Set 27 | kuzovatovo
# Prossing Record 40 of Set 27 | sulangan
# Prossing Record 41 of Set 27 | yalutorovsk
# Prossing Record 42 of Set 27 | haines junction
# Prossing Record 43 of Set 27 | pacific grove
# Prossing Record 44 of Set 27 | honningsvag
# Prossing Record 45 of Set 27 | lakhdenpokhya
# Prossing Record 46 of Set 27 | garden city
# Prossing Record 47 of Set 27 | emerald
# Prossing Record 48 of Set 27 | college
# Prossing Record 49 of Set 27 | gogrial
# Prossing Record 50 of Set 27 | mokrous
# Prossing Record 1 of Set 28 | dennery
# Prossing Record 2 of Set 28 | olafsvik
# Prossing Record 3 of Set 28 | kahului
# Prossing Record 4 of Set 28 | atasu
# Prossing Record 5 of Set 28 | severobaykalsk
# Prossing Record 6 of Set 28 | mys shmidta
# city not found. Skipping...
# Prossing Record 7 of Set 28 | ayna
# Prossing Record 8 of Set 28 | uyuni
# Prossing Record 9 of Set 28 | saint anthony
# Prossing Record 10 of Set 28 | beloha
# Prossing Record 11 of Set 28 | suntar
# Prossing Record 12 of Set 28 | bontang
# Prossing Record 13 of Set 28 | tairua
# Prossing Record 14 of Set 28 | kangaatsiaq
# Prossing Record 15 of Set 28 | chernihiv
# Prossing Record 16 of Set 28 | cumaribo
# city not found. Skipping...
# Prossing Record 17 of Set 28 | cape elizabeth
# city not found. Skipping...
# Prossing Record 18 of Set 28 | badiraguato
# Prossing Record 19 of Set 28 | matadi
# Prossing Record 20 of Set 28 | huanuni
# Prossing Record 21 of Set 28 | areado
# Prossing Record 22 of Set 28 | diego de almagro
# Prossing Record 23 of Set 28 | zhigansk
# Prossing Record 24 of Set 28 | santa cruz
# Prossing Record 25 of Set 28 | krasnyy oktyabr
# Prossing Record 26 of Set 28 | qandala
# Prossing Record 27 of Set 28 | general pico
# Prossing Record 28 of Set 28 | salamiyah
# Prossing Record 29 of Set 28 | coatzacoalcos
# Prossing Record 30 of Set 28 | san borja
# Prossing Record 31 of Set 28 | seoul
# Prossing Record 32 of Set 28 | ngukurr
# city not found. Skipping...
# Prossing Record 33 of Set 28 | baghdad
# Prossing Record 34 of Set 28 | totma
# Prossing Record 35 of Set 28 | kiryu
# Prossing Record 36 of Set 28 | eureka
# Prossing Record 37 of Set 28 | rabak
# Prossing Record 38 of Set 28 | port hardy
# Prossing Record 39 of Set 28 | saldanha
# Prossing Record 40 of Set 28 | kushiro
# Prossing Record 41 of Set 28 | dubai
# Prossing Record 42 of Set 28 | amarante do maranhao
# Prossing Record 43 of Set 28 | bull savanna
# Prossing Record 44 of Set 28 | mergui
# city not found. Skipping...
# Prossing Record 45 of Set 28 | merke
# Prossing Record 46 of Set 28 | ankara
# Prossing Record 47 of Set 28 | madawaska
# Prossing Record 48 of Set 28 | port macquarie
# Prossing Record 49 of Set 28 | tautira
# Prossing Record 50 of Set 28 | phan thiet
# Prossing Record 1 of Set 29 | malwan
# city not found. Skipping...
# Prossing Record 2 of Set 29 | malpe
# Prossing Record 3 of Set 29 | wenling
# Prossing Record 4 of Set 29 | cavalcante
# Prossing Record 5 of Set 29 | yagodnoye
# Prossing Record 6 of Set 29 | santa rosa
# Prossing Record 7 of Set 29 | tessalit
# Prossing Record 8 of Set 29 | deulgaon raja
# Prossing Record 9 of Set 29 | waingapu
# Prossing Record 10 of Set 29 | tungor
# Prossing Record 11 of Set 29 | chulumani
# Prossing Record 12 of Set 29 | silopi
# Prossing Record 13 of Set 29 | ponnani
# Prossing Record 14 of Set 29 | pontecagnano
# Prossing Record 15 of Set 29 | metu
# Prossing Record 16 of Set 29 | ibadan
# Prossing Record 17 of Set 29 | rach gia
# Prossing Record 18 of Set 29 | unity
# Prossing Record 19 of Set 29 | kaoma
# Prossing Record 20 of Set 29 | lorengau
# Prossing Record 21 of Set 29 | bonoua
# Prossing Record 22 of Set 29 | wana
# Prossing Record 23 of Set 29 | rungata
# city not found. Skipping...
# Prossing Record 24 of Set 29 | catamarca
# Prossing Record 25 of Set 29 | axim
# Prossing Record 26 of Set 29 | kloulklubed
# Prossing Record 27 of Set 29 | podor
# Prossing Record 28 of Set 29 | belton
# Prossing Record 29 of Set 29 | bloemfontein
# Prossing Record 30 of Set 29 | gourdon
# Prossing Record 31 of Set 29 | sokolovo
# Prossing Record 32 of Set 29 | pitimbu
# Prossing Record 33 of Set 29 | lavrentiya
# Prossing Record 34 of Set 29 | black river
# Prossing Record 35 of Set 29 | tenenkou
# Prossing Record 36 of Set 29 | akyab
# Prossing Record 37 of Set 29 | amapa
# Prossing Record 38 of Set 29 | shenzhen
# Prossing Record 39 of Set 29 | yatou
# Prossing Record 40 of Set 29 | ardistan
# city not found. Skipping...
# Prossing Record 41 of Set 29 | cabanas
# Prossing Record 42 of Set 29 | rio grande
# Prossing Record 43 of Set 29 | saint-francois
# Prossing Record 44 of Set 29 | finote selam
# Prossing Record 45 of Set 29 | andra
# Prossing Record 46 of Set 29 | cape coast
# Prossing Record 47 of Set 29 | karachi
# Prossing Record 48 of Set 29 | korgen
# Prossing Record 49 of Set 29 | bairiki
# Prossing Record 50 of Set 29 | kargil
# Prossing Record 1 of Set 30 | qui nhon
# Prossing Record 2 of Set 30 | laguna
# Prossing Record 3 of Set 30 | kenai
# Prossing Record 4 of Set 30 | da nang
# Prossing Record 5 of Set 30 | ugoofaaru
# Prossing Record 6 of Set 30 | bathsheba
# Prossing Record 7 of Set 30 | ojinaga
# Prossing Record 8 of Set 30 | anse-bertrand
# Prossing Record 9 of Set 30 | yarmouth
# Prossing Record 10 of Set 30 | amalapuram
# Prossing Record 11 of Set 30 | sal rei
# Prossing Record 12 of Set 30 | kirakira
# Prossing Record 13 of Set 30 | dawlatabad
# Prossing Record 14 of Set 30 | fernandez
# Prossing Record 15 of Set 30 | kuito
# Prossing Record 16 of Set 30 | nyurba
# Prossing Record 17 of Set 30 | grand-santi
# Prossing Record 18 of Set 30 | tommot
# Prossing Record 19 of Set 30 | sao jose da coroa grande
# Prossing Record 20 of Set 30 | boke
# Prossing Record 21 of Set 30 | hantsport
# Prossing Record 22 of Set 30 | namatanai
# Prossing Record 23 of Set 30 | lamu
# Prossing Record 24 of Set 30 | staryy nadym
# Prossing Record 25 of Set 30 | dipkarpaz
# city not found. Skipping...
# Prossing Record 26 of Set 30 | nampula
# Prossing Record 27 of Set 30 | lincoln
# Prossing Record 28 of Set 30 | la ligua
# Prossing Record 29 of Set 30 | narsaq
# Prossing Record 30 of Set 30 | cervo
# Prossing Record 31 of Set 30 | bere
# Prossing Record 32 of Set 30 | kankaanpaa
# Prossing Record 33 of Set 30 | okhotsk
# Prossing Record 34 of Set 30 | linxia
# Prossing Record 35 of Set 30 | erdenet
# Prossing Record 36 of Set 30 | udachnyy
# Prossing Record 37 of Set 30 | kharan
# Prossing Record 38 of Set 30 | laramie
# Prossing Record 39 of Set 30 | nevsehir
# Prossing Record 40 of Set 30 | weligama
# Prossing Record 41 of Set 30 | tomatlan
# Prossing Record 42 of Set 30 | playas
# Prossing Record 43 of Set 30 | anzio
# Prossing Record 44 of Set 30 | storforshei
# Prossing Record 45 of Set 30 | newport
# Prossing Record 46 of Set 30 | saint-pierre
# Prossing Record 47 of Set 30 | oschersleben
# Prossing Record 48 of Set 30 | northam
# Prossing Record 49 of Set 30 | meyungs
# city not found. Skipping...
# Prossing Record 50 of Set 30 | salou
# Prossing Record 1 of Set 31 | taywarah
# Prossing Record 2 of Set 31 | ipameri
# Prossing Record 3 of Set 31 | morondava
# Prossing Record 4 of Set 31 | avera
# Prossing Record 5 of Set 31 | milove
# Prossing Record 6 of Set 31 | palauig
# Prossing Record 7 of Set 31 | manzil salim
# Prossing Record 8 of Set 31 | timizart
# Prossing Record 9 of Set 31 | pandharpur
# Prossing Record 10 of Set 31 | cubuk
# Prossing Record 11 of Set 31 | lamballe
# Prossing Record 12 of Set 31 | gazanjyk
# Prossing Record 13 of Set 31 | port shepstone
# Prossing Record 14 of Set 31 | vanino
# Prossing Record 15 of Set 31 | harbour breton
# Prossing Record 16 of Set 31 | kotka
# Prossing Record 17 of Set 31 | takaka
# Prossing Record 18 of Set 31 | araceli
# Prossing Record 19 of Set 31 | dalvik
# Prossing Record 20 of Set 31 | camacari
# Prossing Record 21 of Set 31 | shiyan
# Prossing Record 22 of Set 31 | lumeje
# Prossing Record 23 of Set 31 | ambanja
# Prossing Record 24 of Set 31 | alpena
# Prossing Record 25 of Set 31 | bandipur
# Prossing Record 26 of Set 31 | samana
# Prossing Record 27 of Set 31 | namwala
# Prossing Record 28 of Set 31 | valparaiso
# Prossing Record 29 of Set 31 | teguldet
# Prossing Record 30 of Set 31 | izhma
# Prossing Record 31 of Set 31 | constitucion
# Prossing Record 32 of Set 31 | stephenville crossing
# Prossing Record 33 of Set 31 | torbat-e jam
# Prossing Record 34 of Set 31 | alto araguaia
# Prossing Record 35 of Set 31 | lillesand
# Prossing Record 36 of Set 31 | bocanda
# Prossing Record 37 of Set 31 | ballina
# Prossing Record 38 of Set 31 | bac lieu
# Prossing Record 39 of Set 31 | jacareacanga
# Prossing Record 40 of Set 31 | buenos aires
# Prossing Record 41 of Set 31 | racine
# ---------------------------
# Data Retrieval complete
# ---------------------------

# %%
# convert the array of dictionaries to a Pandas DataFrame
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Port Augusta      AU -32.5000  137.7667     56.71        68
# 1                    Buluang      PH  13.3068  123.3425     77.79        89
# 2                    Mataura      NZ -46.1927  168.8643     43.48        87
# 3                      Kapaa      US  22.0752 -159.3190     82.38        69
# 4                   Yelizovo      RU  53.1873  158.3805     42.94       100
# 5                 Bredasdorp      ZA -34.5322   20.0403     58.95        32
# 6  Petropavlovsk-Kamchatskiy      RU  53.0452  158.6483     41.59       100
# 7                      Abnub      EG  27.2696   31.1511     80.08        26
# 8                    Rikitea      PF -23.1203 -134.9692     76.68        84
# 9                     Castro      BR -24.7911  -50.0119     63.07        69
#
#    Cloudiness  Wind Speed Weather Description
# 0           5       14.61           clear sky
# 1         100        1.25     overcast clouds
# 2          82        2.62       broken clouds
# 3          75        4.00       broken clouds
# 4          90        0.00     overcast clouds
# 5           4        6.46           clear sky
# 6          90        3.06          light rain
# 7          10       18.52           clear sky
# 8          97       15.68     overcast clouds
# 9          99        4.43     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database./WeathePy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
